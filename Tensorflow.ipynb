# %% [markdown]
# <a href="https://colab.research.google.com/github/Master66999/CodeAlphaIntership/blob/main/Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model = tf.keras.Sequential([

    # Define the input shape
    tf.keras.Input(shape=(1,)),

    # Add a Dense layer
    tf.keras.layers.Dense(units=1)
    ])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 5.1041
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.1912
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 3.4694
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.8980
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.4450
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0852
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7988
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5702
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.3872
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.2401
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.1213
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.0249
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.9461
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.8812
# Epoch 15/500
# ...

# %%
print(f"model predicted: {model.predict(np.array([10.0]), verbose=0).item():.5f}")
